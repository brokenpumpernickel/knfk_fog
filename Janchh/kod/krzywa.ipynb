# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets

# %%
w = widgets.IntSlider( description='a:', min=1, max=10, orientation='horizontal')
display(w)
# Out:
# IntSlider(value=1, continuous_update=False, description='a:', max=10, min=1)

# %%
s = widgets.IntSlider( description='b:', min=1, max=10, orientation='horizontal')
display(s)
# Out:
# IntSlider(value=1, description='b:', max=10, min=1)

# %%
g = widgets.FloatSlider( description='delta:', min=0, max=np.pi, orientation='horizontal', step=0.01)
display(g)
# Out:
# FloatSlider(value=0.0, description='delta:', max=3.141592653589793, step=0.01)

# %%
x,y=0,0
a=w.value
b=s.value
delta=g.value
lx,ly=[],[]
t=0.001

# %%
for i in range(10000):
    x=100*np.sin(a*t*i+delta)
    y=100*np.sin(b*t*i)
    lx.append(x)
    ly.append(y)

# %%
plt.figure(figsize=(5, 5), layout='constrained')
plt.plot(lx, ly,)
plt.title("Lissajous curve")
# Out:
# Text(0.5, 1.0, 'Lissajous curve')
