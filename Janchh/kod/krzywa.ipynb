# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
x,y=0,0
a=1
b=2
delta=np.pi/2
lx,ly=[],[]
t=0.1

# %%
for i in range(100):
    x=100*np.sin(a*t*i+delta)
    y=100*np.sin(b*t*i)
    lx.append(x)
    ly.append(y)

# %%
plt.figure(figsize=(5, 5), layout='constrained')
plt.plot(lx, ly,)
plt.title("Lissajous curve")
# Out:
# Text(0.5, 1.0, 'Lissajous curve')
