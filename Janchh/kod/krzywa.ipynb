# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
x,y=0,0
a=1
b=2
delta=np.pi/2
lx,ly=[],[]

# %%
for t in range(1000):
    x=100*np.sin(a*t+delta)
    y=100*np.sin(b*t)
    lx.append(x)
    ly.append(y)

# %%
plt.plot(lx, ly,"r.", color="green",linewidth=1)
# Out:
# C:\Users\macie\AppData\Local\Temp\ipykernel_8276\3976002548.py:1: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r." (-> color='r'). The keyword argument will take precedence.
#   plt.plot(lx, ly,"r.", color="green",linewidth=1)
